# %%
import matplotlib.pyplot as plt
import numpy as np
import os, errno
import pandas as pd
from scipy.stats import ttest_ind_from_stats
import scipy.signal as signal
from scipy import stats
# %matplotlib nbagg

celltype = 'H2'

csvroot = "C:/Users/Huayi/Google Drive/Desplan Lab/FuncExpt/Ephys/data/"
csvpath = csvroot+'%s/%s.xlsx' %(celltype,celltype)

xls = pd.ExcelFile(csvpath)
#df = pd.read_excel(xls, 'Set1dupe')
df = df.copy()
df
# Out:
#          cells  Sine_12dir_lambda30_1Hz  Sq_LR_12dir_lambda30_1Hz_bgstill  \
# 0          NaN                      NaN                               NaN
# 1   022719fly1                      5.0                              11.0
# 2   030719fly1                      5.0                               7.0
# 3   031519fly1                     15.0                              14.0
# 4   031819fly1                      4.0                               6.0
# 5   032019fly2                      4.0                               6.0
# 6   032619fly1                      4.0                               6.0
# 7          NaN                      NaN                               NaN
# 8          NaN                      NaN                               NaN
# 9          NaN                      NaN                               NaN
# 10         NaN                      NaN                               NaN
# 11         NaN                      NaN                               NaN
# ...

# %%
from utils_LR_PvN_PDND import *

stimulus = 'Sine_PDND_lambda30_zHz'
# spiking = 1
# if spiking: 
#     Meandf,celldf,MeanVdf,cellVdf,Meannormdf,cellnormdf,MeanVnormdf,cellVnormdf,Stddf,StdVdf,Stdnormdf,StdVnormdf =  Mergecells(df,csvroot,stimulus,celltype,spiking)
# else:
#     MeanVdf,cellVdf,MeanVnormdf,cellVnormdf,StdVdf,StdVnormdf = Mergecells(df,csvroot,stimulus,celltype,spiking)

# %%
stimulus = 'Sine_PDND_lambda30_zHz'
#pltmulti('Meandf','Stddf','celldf','AP', csvroot, celltype,stimulus,1,1,1); 
pltmulti('MeanVdf','StdVdf','cellVdf','Vm', csvroot, celltype,stimulus,1,1,1)
#pltmulti('Meannormdf','Stdnormdf','cellnormdf','AP_norm', csvroot,celltype,stimulus,1.08033666, 1.026676936, 0.544829662)
pltmulti('MeanVnormdf','StdVnormdf','cellVnormdf','Vm_norm', csvroot,celltype,stimulus, 0.93187411,1.058244888,0.695163114)
# H2: 0.83616137, 1.064869265, 0.692862319)
# HS: 0.93187411,1.058244888,0.695163114)
# Out:
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib nbagg

from utils_LR_PvN_PDND import *

stimulus = 'Sine_PvN_lambda30_zHz_bgstill'
spiking = 0
if spiking: 
    Meandf,celldf,MeanVdf,cellVdf,Meannormdf,cellnormdf,MeanVnormdf,cellVnormdf,Stddf,StdVdf,Stdnormdf,StdVnormdf =  Mergecells(df,csvroot,stimulus,celltype,spiking)
else:
    MeanVdf,cellVdf,MeanVnormdf,cellVnormdf,StdVdf,StdVnormdf = Mergecells(df,csvroot,stimulus,celltype,spiking)
    Meannormdf=0;Stdnormdf=0;Meandf=0;Stddf=0

# MeanVnormdf = pd.read_csv(csvroot + 'Analysis/' + stimulus + '/'+celltype+'/MeanVnormdf.csv')
# StdVnormdf = pd.read_csv(csvroot + 'Analysis/' + stimulus + '/'+celltype+'/StdVnormdf.csv')
# Meannormdf = pd.read_csv(csvroot + 'Analysis/' + stimulus + '/'+celltype+'/Meannormdf.csv')
# Stdnormdf = pd.read_csv(csvroot + 'Analysis/' + stimulus + '/'+celltype+'/Stdnormdf.csv')

pltPvNz(csvroot,stimulus,MeanVnormdf,StdVnormdf,Meannormdf,Stdnormdf,True)
#pltPvNz(csvroot,stimulus,MeanVdf,StdVdf,Meandf,Stddf,False)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
from utils_LR_PvN_PDND import *

stimulus = 'Sine_PvN_lambda30_zHz_bgstill'
cellVdf = pd.read_csv(csvroot+'Analysis/Sine_PvN_lambda30_zHz_bgstill/' + celltype + '/cellVdf.csv', index_col = 0)
MeanVdf = pd.read_csv(csvroot+'Analysis/Sine_PvN_lambda30_zHz_bgstill/' + celltype + '/MeanVdf.csv', index_col = 0)
cellVnormdf = pd.read_csv(csvroot+'Analysis/Sine_PvN_lambda30_zHz_bgstill/' + celltype + '/cellVnormdf.csv', index_col = 0)
MeanVnormdf = pd.read_csv(csvroot+'Analysis/Sine_PvN_lambda30_zHz_bgstill/' + celltype + '/MeanVnormdf.csv', index_col = 0)

celldf = pd.read_csv(csvroot+'Analysis/Sine_PvN_lambda30_zHz_bgstill/' + celltype + '/celldf.csv', index_col = 0)
Meandf = pd.read_csv(csvroot+'Analysis/Sine_PvN_lambda30_zHz_bgstill/' + celltype + '/Meandf.csv', index_col = 0)
cellnormdf = pd.read_csv(csvroot+'Analysis/Sine_PvN_lambda30_zHz_bgstill/' + celltype + '/cellnormdf.csv', index_col = 0)
Meannormdf = pd.read_csv(csvroot+'Analysis/Sine_PvN_lambda30_zHz_bgstill/' + celltype + '/Meannormdf.csv', index_col = 0)

# %%
tp = 'AP'; ttestdf= ttestPvNz(celldf,tp,csvroot,stimulus, celltype,MeanVdf)
tp = 'APnorm'; ttestnormdf= ttestPvNz(cellnormdf,tp,csvroot,stimulus, celltype,MeanVdf)
tp = 'V'; ttestVdf= ttestPvNzV(cellVdf,tp,csvroot,stimulus, celltype,MeanVdf)
tp = 'Vnorm'; ttestVnormdf= ttestPvNzV(cellVnormdf,tp,csvroot,stimulus, celltype,MeanVnormdf)
# Out:
# C:\Users\Huayi\Anaconda3\lib\site-packages\scipy\stats\morestats.py:2385: UserWarning: Warning: sample size too small for normal approximation.
#   warnings.warn("Warning: sample size too small for normal approximation.")
